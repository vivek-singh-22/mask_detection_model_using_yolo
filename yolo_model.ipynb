# %%
from ultralytics import YOLO

# %%
pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.1.15
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page:
# Author: Glenn Jocher, Ayush Chaurasia, Jing Qiu
# Author-email:
# License: AGPL-3.0
# Location: c:\Users\vivek\anaconda3\envs\Mask_detection\Lib\site-packages
# Requires: matplotlib, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, thop, torch, torchvision, tqdm
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=60 imgsz=416 batch=16 workers=4 plots=True patience=10
# Out:
# ^C
# New https://pypi.org/project/ultralytics/8.3.160 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.15 🚀 Python-3.11.11 torch-2.5.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
# !yolo task=detect mode=predict model=run\detect\train\weights\best.pt source=data/images/test imgsz=416 batch=16 plots=True conf=.25 iou=0.5
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.11.11 torch-2.5.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/86 c:\CDAC\DNN_programs_Assignments\Mask_detection\data\images\test\maksssksksss103.png: 320x416 4 with_masks, 1 without_mask, 74.5ms
# image 2/86 c:\CDAC\DNN_programs_Assignments\Mask_detection\data\images\test\maksssksksss114.png: 256x416 1 with_mask, 1 without_mask, 49.8ms
# image 3/86 c:\CDAC\DNN_programs_Assignments\Mask_detection\data\images\test\maksssksksss126.png: 416x288 2 with_masks, 2 without_masks, 52.4ms
# image 4/86 c:\CDAC\DNN_programs_Assignments\Mask_detection\data\images\test\maksssksksss128.png: 416x320 1 without_mask, 50.8ms
# image 5/86 c:\CDAC\DNN_programs_Assignments\Mask_detection\data\images\test\maksssksksss153.png: 288x416 1 with_mask, 1 without_mask, 46.4ms
# ...

# %%
#from ultralytics import YOLO

# Load a model
#model = YOLO("yolo11n.yaml")  # build a new model from YAML
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
#model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="data.yaml", epochs=100, imgsz=416, plots=True,
                      batch=32, 
                      device='0', 
                      workers=4, 
                      project='runs/train', 
                      name='yolo11n',
                      exist_ok=True,
                      save_period=1,
                      save_json=True,
                      cache=True)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:15<00:00, 429kB/s]
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[15], line 5
#       1 #from ultralytics import YOLO
#       2
#       3 # Load a model
#       4 #model = YOLO("yolo11n.yaml")  # build a new model from YAML
# ----> 5 model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
#       6 #model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights
#       7
#       8 # Train the model
#       9 results = model.train(data="data.yaml", epochs=100, imgsz=416, plots=True,
#      10                       batch=32,
#      11                       device='0',
#    (...)     17                       save_json=True,
#      18                       cache=True)
#
# ...
